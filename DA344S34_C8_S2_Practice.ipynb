# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("DS1_C8_S2_SmartCarRiding_Data_Practice.csv")
df
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
df['fare_amount']
# Out:
# 0          7.5
# 1          7.7
# 2         12.9
# 3          5.3
# 4         16.0
#           ...
# 199995     3.0
# 199996     7.5
# 199997    30.9
# 199998    14.5
# 199999    14.1
# Name: fare_amount, Length: 200000, dtype: float64

# %%
df.shape
# Out:
# (200000, 9)

# %% [markdown]
# ## Task_2

# %%
# Step 1: Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Read the CSV file
df = pd.read_csv('DS1_C8_S2_SmartCarRiding_Data_Practice.csv')
df
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
# Step 3: Plot the Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['fare_amount'])
plt.title('Box Plot of Fare Amount')
plt.xlabel('Fare Amount')
plt.show()

# %%
# Step 4: the IQR for outlier treatment
Q1 = df['fare_amount'].quantile(0.25)
Q3 = df['fare_amount'].quantile(0.75)
IQR = Q3 - Q1

print(Q1)
print(Q3)
print(IQR)
# Out:
# 6.0
# 12.5
# 6.5

# %%
# Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound)
print(upper_bound)
# Out:
# -3.75
# 22.25

# %%
# Step 5: Filter out outliers
df_filtered = df[(df['fare_amount'] >= lower_bound) & (df['fare_amount'] <= upper_bound)]
df_filtered
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199994   3189201  42:00.0         12.0  2014-01-31 14:42:00 UTC
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
# Display the filtered DataFrame
df_filtered.head()
# Out:
#       Index      key  fare_amount          pickup_datetime  pickup_longitude  \
# 0  24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1  27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2  44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3  25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4  17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC        -73.925023
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0        40.738354         -73.999512         40.723217                1
# 1        40.728225         -73.994710         40.750325                1
# 2        40.740770         -73.962565         40.772647                1
# 3        40.790844         -73.965316         40.803349                3
# 4        40.744085         -73.973082         40.761247                5

# %% [markdown]
# ## Task_3

# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Read the CSV file
df = pd.read_csv('DS1_C8_S2_SmartCarRiding_Data_Practice.csv')
df
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
# Step 3: Define the sample sizes
sample_sizes = [10, 15, 30, 200, 1000, 5000, 10000, 50000, 100000]
sample_sizes
# Out:
# [10, 15, 30, 200, 1000, 5000, 10000, 50000, 100000]

# %%
# Step 4: Loop through sample sizes and plot distributions
for size in sample_sizes:
    # Check if the sample size is larger than the dataset
    if size > len(df):
        print(f"Sample size {size} is larger than the dataset size.")
        continue

# %%
# Generate a random sample of the specified size
sample = df['fare_amount'].sample(n=size, random_state=1)
sample
# Out:
# 49673      4.0
# 171551     6.1
# 5506       8.5
# 38370      4.9
# 36930      6.5
#           ...
# 77858     34.5
# 60260     10.0
# 82973      9.0
# 68223     11.3
# 154298    11.5
# Name: fare_amount, Length: 100000, dtype: float64

# %%
# Plot the distribution of the sample
plt.figure(figsize=(12, 6))
sns.histplot(sample, kde=True, bins=30, color='skyblue')
plt.title(f'Distribution Plot for Sample Size = {size}')
plt.xlabel('Fare Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\Madhu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Interpretation:-Samples with sizes greater than or equal to 200 typically exhibit distributions that more closely approximate a normal distribution.

# %% [markdown]
# ## Task_4

# %%
# Import necessary libraries
import pandas as pd

# Read the CSV file
df = pd.read_csv('DS1_C8_S2_SmartCarRiding_Data_Practice.csv')
df
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
# Extract sample data using random sampling with replacement
sample_df = df.sample(200, replace=True, random_state=1)

# Display the first few rows of the sample
sample_df.head()
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 128037  34880869  32:56.0        49.57  2010-12-26 14:32:56 UTC
# 5192    10514640  28:00.0        14.00  2012-11-27 21:28:00 UTC
# 50057   39371632  09:00.0        12.90  2010-08-23 22:09:00 UTC
# 109259  37753824  22:30.0         6.00  2013-10-09 08:22:30 UTC
# 73349   48099710  23:07.0         6.10  2012-01-17 20:23:07 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 128037        -73.965069        40.791239         -73.782221
# 5192          -73.776675        40.645348         -73.819305
# 50057         -73.994013        40.724697         -73.994923
# 109259        -73.981399        40.741402         -73.991322
# 73349         -73.988700        40.748039         -74.003445
#
#         dropoff_latitude  passenger_count
# 128037         40.648726                1
# 5192           40.670327                2
# 50057          40.762680                1
# ...

# %% [markdown]
# # Task_5

# %%
import pandas as pd
import numpy as np

# %%
# Sample of size 200
sample = df.sample(200, replace=False,random_state=1)
sample
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 49673   31740392  26:00.0          4.0  2014-07-06 20:26:00 UTC
# 171551  34876499  58:00.0          6.1  2010-09-16 12:58:00 UTC
# 5506    46355351  22:00.0          8.5  2014-07-14 19:22:00 UTC
# 38370   15469840  56:00.0          4.9  2012-05-29 07:56:00 UTC
# 36930    9321673  27:38.0          6.5  2010-07-20 08:27:38 UTC
# ...          ...      ...          ...                      ...
# 132344  29137243  56:00.0          6.5  2009-11-30 12:56:00 UTC
# 168966  28743730  42:59.0         14.1  2010-01-12 15:42:59 UTC
# 84315   15468935  39:49.0          7.5  2014-07-30 19:39:49 UTC
# 136579  46127452  30:58.0          5.3  2011-08-12 08:30:58 UTC
# 12478   49883897  04:00.0          6.5  2012-07-25 19:04:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 49673         -74.002573        40.723802         -73.996727
# 171551        -73.987995        40.766362         -73.982422
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DS1_C8_S2_SmartCarRiding_Data_Practice.csv')
data
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
## Calculate Central Tendency and Dispersion for Entire Data

entire_data_mean = data.mean()
entire_data_median = data.median()
entire_data_std = data.std()
entire_data_variance = data.var()

# %%
print("Entire Data - Mean:")
print(entire_data_mean)
print("Entire Data - Median:")
print(entire_data_median)
print("Entire Data - Standard Deviation:")
print(entire_data_std)
print("Entire Data - Variance:")
print(entire_data_variance)

# %%
sample_data = data.sample(200, random_state=1)
sample_data

# %%
## Calculate Central Tendency and Dispersion for Sampled Data
sample_mean = sample_data.mean()
sample_median = sample_data.median()
sample_std = sample_data.std()
sample_variance = sample_data.var()

# %%
print("Sample Data - Mean:")
print(sample_mean)
print("Sample Data - Median:")
print(sample_median)
print("Sample Data - Standard Deviation:")
print(sample_std)
print("Sample Data - Variance:")
print(sample_variance)

# %%
# Check for Central Limit Theorem (CLT)
# A visual inspection of the sample distribution can be helpful

plt.hist(sample_data.mean(), bins=30, alpha=0.7, color='blue')
plt.title('Histogram of Sample Mean')
plt.xlabel('Mean Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Justify Based on Results :-  If the sample mean is close to the population mean and the sample distribution of the means is approximately normal, this supports the Central Limit Theorem and confirms that the sample data is suitable for analysis.
